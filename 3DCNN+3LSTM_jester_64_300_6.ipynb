# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers.convolutional import Conv3D, MaxPooling3D,Conv2D,AveragePooling2D,AveragePooling3D
from keras.layers import Dense, GlobalAveragePooling3D,GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler,ReduceLROnPlateau
from keras.optimizers import SGD, RMSprop, Adadelta
from keras.utils import np_utils, generic_utils
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional_recurrent import ConvLSTM2D

import theano
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.cross_validation import train_test_split
from sklearn import cross_validation
from sklearn import preprocessing
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /opt/conda/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# image specification
img_rows,img_cols=64,64

# Training data

X_tr=[]           # variable to store entire dataset

# %%
'''
import os
from tqdm import tqdm
ls_path_10 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/")
listing_10 = os.listdir(ls_path_10)
for ls_1 in listing_10:
    ls_path_11 = os.path.join(ls_path_10,ls_1)
    listing_11 = os.listdir(ls_path_11)
    for ls in tqdm(listing_11):
        listing_stop_10 = os.listdir(os.path.join(ls_path_11,ls)) 
        #print(ls)
        img_depth = len(listing_stop_10)
        if img_depth < 20:
            print(img_depth)
            print(ls)
'''
# Out:
# '\nimport os\nfrom tqdm import tqdm\nls_path_10 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/")\nlisting_10 = os.listdir(ls_path_10)\nfor ls_1 in listing_10:\n    ls_path_11 = os.path.join(ls_path_10,ls_1)\n    listing_11 = os.listdir(ls_path_11)\n    for ls in tqdm(listing_11):\n        listing_stop_10 = os.listdir(os.path.join(ls_path_11,ls)) \n        #print(ls)\n        img_depth = len(listing_stop_10)\n        if img_depth < 20:\n            print(img_depth)\n            print(ls)\n'

# %%
from tqdm import tqdm

ls_path = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Rolling Hand Backward")
listing = os.listdir(ls_path)

for ls in tqdm(listing):
    listing_stop = sorted(os.listdir(os.path.join(ls_path,ls))) 
    #print(ls)
    #img_depth = len(listing_stop)
    #if img_depth < 15:
        #print(img_depth)
        #print(ls)
    frames = []
    img_depth=0
    for imgs in listing_stop:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path,ls),imgs)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #print(frame.shape)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #print(frame.shape)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 87.27it/s]
# (16, 64, 64, 3)
# 300

# %%
from tqdm import tqdm

ls_path_2 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Rolling Hand Forward")
listing_2 = os.listdir(ls_path_2)

for ls_2 in tqdm(listing_2):
    listing_stop_2 = sorted(os.listdir(os.path.join(ls_path_2,ls_2)))
    #print(ls_2)
    #img_depth = len(listing_stop_2)
    #print(img_depth)
    frames = []
    img_depth= 0
    for imgs_2 in listing_stop_2:
        if img_depth < 16:
            img = os.path.join(os.path.join(ls_path_2,ls_2),imgs_2)
            #ret, frame = cap.read()
            #print(img)
            frame = cv2.imread(img)
            #print(imgs_2)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 85.77it/s]
# (16, 64, 64, 3)
# 600

# %%
from tqdm import tqdm

ls_path_3 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Stop")
listing_3 = os.listdir(ls_path_3)

for ls_3 in tqdm(listing_3):
    listing_stop_3 = sorted(os.listdir(os.path.join(ls_path_3,ls_3)))
    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_3 in listing_stop_3:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_3,ls_3),imgs_3)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 83.92it/s]
# (16, 64, 64, 3)
# 900

# %%
from tqdm import tqdm

ls_path_4 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Swiping Left")
listing_4 = os.listdir(ls_path_4)

for ls_4 in tqdm(listing_4):
    listing_stop_4 = sorted(os.listdir(os.path.join(ls_path_4,ls_4)))

    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_4 in listing_stop_4:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_4,ls_4),imgs_4)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 299/299 [00:03<00:00, 89.76it/s]
# (16, 64, 64, 3)
# 1199

# %%
print(ls_4)
# Out:
# 7380

# %%
from tqdm import tqdm

ls_path_5 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Swiping Right")
listing_5 = os.listdir(ls_path_5)

for ls_5 in tqdm(listing_5):
    listing_stop_5 = sorted(os.listdir(os.path.join(ls_path_5,ls_5)))

    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_5 in listing_stop_5:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_5,ls_5),imgs_5)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 91.06it/s]
# (16, 64, 64, 3)
# 1499

# %%
from tqdm import tqdm

ls_path_6 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/No gesture")
listing_6 = os.listdir(ls_path_6)

for ls_6 in tqdm(listing_6):
    listing_stop_6 = sorted(os.listdir(os.path.join(ls_path_6,ls_6)))
    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_6 in listing_stop_6:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_6,ls_6),imgs_6)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 89.70it/s]
# (16, 64, 64, 3)
# 1799

# %%
X_tr_array = np.array(X_tr)   # convert the frames read into array

num_samples = len(X_tr_array) 
print (num_samples)
# Out:
# 1799

# %%
'''
label=np.ones((num_samples,),dtype = int)
label[0:74]= 0
label[75:136] = 1
'''
# Out:
# '\nlabel=np.ones((num_samples,),dtype = int)\nlabel[0:74]= 0\nlabel[75:136] = 1\n'

# %%
label=np.ones((num_samples,),dtype = int)
label[0:300]= 0
label[300:600] = 1
label[600:900] = 2
label[900:1199] = 3
label[1199:1499] = 4
label[1499:1799] = 5

# %%
img_depth = 16
train_data = [X_tr_array,label]

(X_train, y_train) = (train_data[0],train_data[1])
print('X_Train shape:', X_train.shape)

train_set = np.zeros((num_samples, img_depth, img_cols,img_rows,3))

for h in range(num_samples):
    train_set[h][:][:][:][:]=X_train[h,:,:,:]
  

patch_size = 16    # img_depth or number of frames used for each video

print(train_set.shape, 'train samples')
# Out:
# X_Train shape: (1799, 16, 64, 64, 3)
# (1799, 16, 64, 64, 3) train samples

# %%
# CNN Training parameters


nb_classes = 6

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)

# %%
# Pre-processing

train_set = train_set.astype('float32')
print(np.mean(train_set))
train_set -= np.mean(train_set)
print(np.max(train_set))
train_set /=np.max(train_set)
# Out:
# 108.01355
# 146.98645

# %%
# Define model
weight_decay = 0.00005
import tensorflow as tf
keras=tf.contrib.keras
l2=keras.regularizers.l2

model = Sequential()
model.add(Conv3D(16,(3,3,3),
                        input_shape=(patch_size, img_cols, img_rows, 3),
                        activation='relu'))
model.add(Conv3D(16,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2a_a', activation = 'relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(32,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2b_a', activation = 'relu'))
model.add(Conv3D(32,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2b_b', activation = 'relu'))
model.add(MaxPooling3D(pool_size=(1, 2,2)))


model.add(Conv3D(64,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2c_a', activation = 'relu'))
model.add(Conv3D(64,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2c_b', activation = 'relu'))
model.add(Conv3D(64,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2c_c', activation = 'relu'))
model.add(MaxPooling3D(pool_size=(1, 2,2)))


model.add(Conv3D(128,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2d_a', activation = 'relu'))
model.add(Conv3D(128,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2d_b', activation = 'relu'))
model.add(Conv3D(128,(3,3,3), strides=(1,1,1),padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv3D_2d_c', activation = 'relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))






model.add(ConvLSTM2D(filters=64, kernel_size=(3,3),
                  strides=(1,1),padding='same',
                      kernel_initializer='he_normal', recurrent_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay), recurrent_regularizer=l2(weight_decay),
                      return_sequences=True, name='gatedclstm2d_2'))

model.add(ConvLSTM2D(filters=64, kernel_size=(3,3),
                  strides=(1,1),padding='same',
                      kernel_initializer='he_normal', recurrent_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay), recurrent_regularizer=l2(weight_decay),
                      return_sequences=True, name='gatedclstm2d_3'))

model.add(ConvLSTM2D(filters=64, kernel_size=(3,3),
                  strides=(1,1),padding='same',
                      kernel_initializer='he_normal', recurrent_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay), recurrent_regularizer=l2(weight_decay),
                      return_sequences=True, name='gatedclstm2d_4'))


#model.add(MaxPooling3D(pool_size=(nb_pool[0], nb_pool[0], nb_pool[0])))
#model.add(Flatten())
model.add(GlobalAveragePooling3D())
model.add(Dropout(0.5))
model.add(Dense(nb_classes,kernel_initializer='normal'))

model.add(Activation('softmax'))

# %%
#low resolution network
weight_decay = 0.005
from keras import regularizers
model = Sequential()
model.add(MaxPooling3D(pool_size=(1, 2, 2),input_shape=(patch_size, 57, 125, 3)))

model.add(Conv3D(8,(1,5,5),activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Conv3D(8,(5,1,1),activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(32,(1,5,5), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Conv3D(32,(3,1,1), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(64,(1,3,5), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Conv3D(64,(3,1,1), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(1, 1, 4 )))



#model.add(Conv3D(128,3,3,3, activation='relu'))
#model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2),
#border_mode='valid'))
#model.add(BatchNormalization())

model.add(Flatten())
#model.add(GlobalAveragePooling3D())
model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Dense(nb_classes,kernel_initializer='normal',kernel_regularizer=regularizers.l2(weight_decay)))

model.add(Activation('softmax'))

# %%
#low resolution network
weight_decay = 0.005
from keras import regularizers
model = Sequential()
model.add(MaxPooling3D(pool_size=(1, 2, 2),input_shape=(patch_size, 57, 125, 3)))

model.add(Conv3D(8,(5,5,5),activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(32,(3,5,5), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(64,(3,3,5), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(1, 1, 4 )))



#model.add(Conv3D(128,3,3,3, activation='relu'))
#model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2),
#border_mode='valid'))
#model.add(BatchNormalization())

model.add(Flatten())
#model.add(GlobalAveragePooling3D())
model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Dense(nb_classes,kernel_initializer='normal',kernel_regularizer=regularizers.l2(weight_decay)))

model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_3 (Conv3D)            (None, 14, 62, 62, 16)    1312
# _________________________________________________________________
# Conv3D_2a_a (Conv3D)         (None, 14, 62, 62, 16)    6912
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 7, 31, 31, 16)     0
# _________________________________________________________________
# Conv3D_2b_a (Conv3D)         (None, 7, 31, 31, 32)     13824
# _________________________________________________________________
# Conv3D_2b_b (Conv3D)         (None, 7, 31, 31, 32)     27648
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 7, 15, 15, 32)     0
# _________________________________________________________________
# Conv3D_2c_a (Conv3D)         (None, 7, 15, 15, 64)     55296
# _________________________________________________________________
# Conv3D_2c_b (Conv3D)         (None, 7, 15, 15, 64)     110592
# _________________________________________________________________
# Conv3D_2c_c (Conv3D)         (None, 7, 15, 15, 64)     110592
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 7, 7, 7, 64)       0
# _________________________________________________________________
# Conv3D_2d_a (Conv3D)         (None, 7, 7, 7, 128)      221184
# _________________________________________________________________
# Conv3D_2d_b (Conv3D)         (None, 7, 7, 7, 128)      442368
# _________________________________________________________________
# Conv3D_2d_c (Conv3D)         (None, 7, 7, 7, 128)      442368
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 7, 3, 3, 128)      0
# _________________________________________________________________
# gatedclstm2d_2 (ConvLSTM2D)  (None, 7, 3, 3, 64)       442624
# _________________________________________________________________
# gatedclstm2d_3 (ConvLSTM2D)  (None, 7, 3, 3, 64)       295168
# _________________________________________________________________
# gatedclstm2d_4 (ConvLSTM2D)  (None, 7, 3, 3, 64)       295168
# _________________________________________________________________
# global_average_pooling3d_3 ( (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 390
# _________________________________________________________________
# activation_3 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 2,465,446
# Trainable params: 2,465,446
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
#os.chdir('///home/jovyan/program/DL/11_1下tensorflow_simpson')
save_dir = os.path.join(os.getcwd(),'saved_model')
print(os.getcwd())
model_name = "3DCNN+3LSTM_64_6_jester"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor = 'val_acc', 
                            save_best_only=True, verbose=1)
#earlystop
earlystop = EarlyStopping(monitor='val_loss', patience=50, verbose =1)
# Out:
# /home/jovyan/program/project/3DCNN

# %%
sgd = SGD(lr=0.005,  momentum=0.9, nesterov=False)
rms = RMSprop(decay=1e-6)
ada = Adadelta(lr=0.1,decay=1e-6)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              #optimizer=ada,
              #optimizer = Adam(lr=0.0001),
              metrics=['acc'])
# Split the data

# %%
X_train_new, X_val_new, y_train_new,y_val_new = train_test_split(train_set, Y_train, test_size=0.2, random_state=20)

# %%
batch_size = 32
nb_epoch =300
#steps_per_epoch=int((len(X_val_new)*1.5)/batch_size)
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.05, 
                               cooldown=0, patience=10, min_lr=0.005/(2^4),verbose=1)
hist = model.fit(
    X_train_new,
    y_train_new,
    validation_data=(X_val_new,y_val_new),
    batch_size=batch_size,
    epochs = nb_epoch,
    shuffle=True,
    callbacks=[checkpoint,lr_reducer]
    )
# Out:
# Train on 1439 samples, validate on 360 samples
# Epoch 1/300
# 1439/1439 [==============================] - 13s 9ms/step - loss: 2.0116 - acc: 0.1598 - val_loss: 2.0116 - val_acc: 0.1611
#
# Epoch 00001: val_acc improved from -inf to 0.16111, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN+3LSTM_64_6_jester
# Epoch 2/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0117 - acc: 0.1647 - val_loss: 2.0124 - val_acc: 0.1528
#
# Epoch 00002: val_acc did not improve from 0.16111
# Epoch 3/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0108 - acc: 0.1640 - val_loss: 2.0125 - val_acc: 0.1583
#
# Epoch 00003: val_acc did not improve from 0.16111
# Epoch 4/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0107 - acc: 0.1654 - val_loss: 2.0130 - val_acc: 0.1444
#
# Epoch 00004: val_acc did not improve from 0.16111
# Epoch 5/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0112 - acc: 0.1661 - val_loss: 2.0122 - val_acc: 0.1444
#
# Epoch 00005: val_acc did not improve from 0.16111
# Epoch 6/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0108 - acc: 0.1682 - val_loss: 2.0122 - val_acc: 0.1556
#
# Epoch 00006: val_acc did not improve from 0.16111
# Epoch 7/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0107 - acc: 0.1605 - val_loss: 2.0126 - val_acc: 0.1417
#
# Epoch 00007: val_acc did not improve from 0.16111
# Epoch 8/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0098 - acc: 0.1744 - val_loss: 2.0125 - val_acc: 0.1472
#
# Epoch 00008: val_acc did not improve from 0.16111
# Epoch 9/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0094 - acc: 0.1779 - val_loss: 2.0115 - val_acc: 0.1500
#
# Epoch 00009: val_acc did not improve from 0.16111
# Epoch 10/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0106 - acc: 0.1689 - val_loss: 2.0126 - val_acc: 0.1500
#
# Epoch 00010: val_acc did not improve from 0.16111
# Epoch 11/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0097 - acc: 0.1696 - val_loss: 2.0118 - val_acc: 0.1611
#
# Epoch 00011: val_acc did not improve from 0.16111
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 12/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0092 - acc: 0.1814 - val_loss: 2.0121 - val_acc: 0.1472
#
# Epoch 00012: val_acc did not improve from 0.16111
# Epoch 13/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0089 - acc: 0.1703 - val_loss: 2.0120 - val_acc: 0.1500
#
# Epoch 00013: val_acc did not improve from 0.16111
# Epoch 14/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0092 - acc: 0.1835 - val_loss: 2.0119 - val_acc: 0.1500
#
# Epoch 00014: val_acc did not improve from 0.16111
# Epoch 15/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0090 - acc: 0.1710 - val_loss: 2.0119 - val_acc: 0.1556
#
# Epoch 00015: val_acc did not improve from 0.16111
# Epoch 16/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0081 - acc: 0.1974 - val_loss: 2.0119 - val_acc: 0.1528
#
# Epoch 00016: val_acc did not improve from 0.16111
# Epoch 17/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0089 - acc: 0.1814 - val_loss: 2.0118 - val_acc: 0.1472
#
# Epoch 00017: val_acc did not improve from 0.16111
# Epoch 18/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0098 - acc: 0.1619 - val_loss: 2.0117 - val_acc: 0.1528
#
# Epoch 00018: val_acc did not improve from 0.16111
# Epoch 19/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0095 - acc: 0.1696 - val_loss: 2.0118 - val_acc: 0.1500
#
# Epoch 00019: val_acc did not improve from 0.16111
# Epoch 20/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0083 - acc: 0.1946 - val_loss: 2.0117 - val_acc: 0.1500
#
# Epoch 00020: val_acc did not improve from 0.16111
# Epoch 21/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0081 - acc: 0.1842 - val_loss: 2.0116 - val_acc: 0.1500
#
# Epoch 00021: val_acc did not improve from 0.16111
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 22/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0083 - acc: 0.1939 - val_loss: 2.0116 - val_acc: 0.1556
#
# Epoch 00022: val_acc did not improve from 0.16111
# Epoch 23/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0084 - acc: 0.1876 - val_loss: 2.0117 - val_acc: 0.1583
#
# Epoch 00023: val_acc did not improve from 0.16111
# Epoch 24/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0082 - acc: 0.1946 - val_loss: 2.0115 - val_acc: 0.1528
#
# Epoch 00024: val_acc did not improve from 0.16111
# Epoch 25/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0086 - acc: 0.1758 - val_loss: 2.0115 - val_acc: 0.1583
#
# Epoch 00025: val_acc did not improve from 0.16111
# Epoch 26/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0084 - acc: 0.1883 - val_loss: 2.0114 - val_acc: 0.1611
#
# Epoch 00026: val_acc did not improve from 0.16111
# Epoch 27/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.0079 - acc: 0.1855 - val_loss: 2.0116 - val_acc: 0.1583
#
# Epoch 00027: val_acc did not improve from 0.16111
# Epoch 28/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 2.
300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.6246 - acc: 0.8138 - val_loss: 1.0524 - val_acc: 0.6806
#
# Epoch 00172: val_acc did not improve from 0.71111
# Epoch 173/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.6042 - acc: 0.8200 - val_loss: 0.9981 - val_acc: 0.7028
#
# Epoch 00173: val_acc did not improve from 0.71111
# Epoch 174/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5644 - acc: 0.8284 - val_loss: 1.0004 - val_acc: 0.7222
#
# Epoch 00174: val_acc improved from 0.71111 to 0.72222, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN+3LSTM_64_6_jester
# Epoch 175/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5513 - acc: 0.8582 - val_loss: 1.0442 - val_acc: 0.6972
#
# Epoch 00175: val_acc did not improve from 0.72222
#
# Epoch 00175: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 176/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5529 - acc: 0.8436 - val_loss: 1.0057 - val_acc: 0.7056
#
# Epoch 00176: val_acc did not improve from 0.72222
# Epoch 177/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5876 - acc: 0.8284 - val_loss: 1.0258 - val_acc: 0.7000
#
# Epoch 00177: val_acc did not improve from 0.72222
# Epoch 178/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5801 - acc: 0.8339 - val_loss: 1.0861 - val_acc: 0.6833
#
# Epoch 00178: val_acc did not improve from 0.72222
# Epoch 179/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.6260 - acc: 0.8138 - val_loss: 1.0756 - val_acc: 0.7083
#
# Epoch 00179: val_acc did not improve from 0.72222
# Epoch 180/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5912 - acc: 0.8284 - val_loss: 1.0868 - val_acc: 0.6833
#
# Epoch 00180: val_acc did not improve from 0.72222
# Epoch 181/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5670 - acc: 0.8471 - val_loss: 1.0521 - val_acc: 0.7056
#
# Epoch 00181: val_acc did not improve from 0.72222
# Epoch 182/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5466 - acc: 0.8450 - val_loss: 1.0749 - val_acc: 0.6917
#
# Epoch 00182: val_acc did not improve from 0.72222
# Epoch 183/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5534 - acc: 0.8409 - val_loss: 1.1018 - val_acc: 0.6944
#
# Epoch 00183: val_acc did not improve from 0.72222
# Epoch 184/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5609 - acc: 0.8464 - val_loss: 1.0078 - val_acc: 0.7139
#
# Epoch 00184: val_acc did not improve from 0.72222
# Epoch 185/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5434 - acc: 0.8513 - val_loss: 1.0263 - val_acc: 0.7167
#
# Epoch 00185: val_acc did not improve from 0.72222
#
# Epoch 00185: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 186/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5271 - acc: 0.8471 - val_loss: 1.0728 - val_acc: 0.7083
#
# Epoch 00186: val_acc did not improve from 0.72222
# Epoch 187/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5174 - acc: 0.8707 - val_loss: 1.0542 - val_acc: 0.7111
#
# Epoch 00187: val_acc did not improve from 0.72222
# Epoch 188/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5564 - acc: 0.8388 - val_loss: 1.0644 - val_acc: 0.7361
#
# Epoch 00188: val_acc improved from 0.72222 to 0.73611, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN+3LSTM_64_6_jester
# Epoch 189/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5645 - acc: 0.8346 - val_loss: 1.0247 - val_acc: 0.7000
#
# Epoch 00189: val_acc did not improve from 0.73611
# Epoch 190/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5402 - acc: 0.8520 - val_loss: 1.1549 - val_acc: 0.6861
#
# Epoch 00190: val_acc did not improve from 0.73611
# Epoch 191/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5512 - acc: 0.8436 - val_loss: 1.0713 - val_acc: 0.7278
#
# Epoch 00191: val_acc did not improve from 0.73611
# Epoch 192/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5774 - acc: 0.8284 - val_loss: 1.0518 - val_acc: 0.7194
#
# Epoch 00192: val_acc did not improve from 0.73611
# Epoch 193/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5986 - acc: 0.8297 - val_loss: 1.1045 - val_acc: 0.7111
#
# Epoch 00193: val_acc did not improve from 0.73611
# Epoch 194/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5626 - acc: 0.8409 - val_loss: 1.1083 - val_acc: 0.7278
#
# Epoch 00194: val_acc did not improve from 0.73611
# Epoch 195/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5376 - acc: 0.8436 - val_loss: 1.0706 - val_acc: 0.6944
#
# Epoch 00195: val_acc did not improve from 0.73611
#
# Epoch 00195: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 196/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5196 - acc: 0.8582 - val_loss: 1.0821 - val_acc: 0.7250
#
# Epoch 00196: val_acc did not improve from 0.73611
# Epoch 197/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4963 - acc: 0.8805 - val_loss: 1.0964 - val_acc: 0.7361
#
# Epoch 00197: val_acc did not improve from 0.73611
# Epoch 198/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4820 - acc: 0.8909 - val_loss: 1.0780 - val_acc: 0.7222
#
# Epoch 00198: val_acc did not improve from 0.73611
# Epoch 199/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4773 - acc: 0.8965 - val_loss: 1.1053 - val_acc: 0.7111
#
# Epoch 00199: val_acc did not improve from 0.73611
# Epoch 200/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4678 - acc: 0.8999 - val_loss: 1.1070 - val_acc: 0.7250
#
# Epoch 00200: val_acc did not improve from 0.73611
# Epoch 201/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4602 - acc: 0.9138 - val_loss: 1.1149 - val_acc: 0.7167
#
# Epoch 00201: val_acc did not improve from 0.73611
# Epoch 202/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4606 - acc: 0.9097 - val_loss: 1.1200 - val_acc: 0.7222
#
# Epoch 00202: val_acc did not improve from 0.73611
# Epoch 203/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4432 - acc: 0.9284 - val_loss: 1.1187 - val_acc: 0.7139
#
# Epoch 00203: val_acc did not improve from 0.73611
# Epoch 204/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4473 - acc: 0.9256 - val_loss: 1.1150 - val_acc: 0.7222
#
# Epoch 00204: val_acc did not improve from 0.73611
# Epoch 205/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4288 - acc: 0.9305 - val_loss: 1.1147 - val_acc: 0.7222
#
# Epoch 00205: val_acc did not improve from 0.73611
#
# Epoch 00205: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 206/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4168 - acc: 0.9416 - val_loss: 1.1572 - val_acc: 0.7139
#
# Epoch 00206: val_acc did not improve from 0.73611
# Epoch 207/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4199 - acc: 0.9361 - val_loss: 1.1633 - val_acc: 0.7167
#
# Epoch 00207: val_acc did not improve from 0.73611
# Epoch 208/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4164 - acc: 0.9451 - val_loss: 1.1552 - val_acc: 0.7056
#
# Epoch 00208: val_acc did not improve from 0.73611
# Epoch 209/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4029 - acc: 0.9527 - val_loss: 1.1205 - val_acc: 0.7056
#
# Epoch 00209: val_acc did not improve from 0.73611
# Epoch 210/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4115 - acc: 0.9395 - val_loss: 1.1187 - val_acc: 0.7361
#
# Epoch 00210: val_acc did not improve from 0.73611
# Epoch 211/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4616 - acc: 0.9270 - val_loss: 1.2067 - val_acc: 0.6889
#
# Epoch 00211: val_acc did not improve from 0.73611
# Epoch 212/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5470 - acc: 0.8860 - val_loss: 1.2999 - val_acc: 0.6889
#
# Epoch 00212: val_acc did not improve from 0.73611
# Epoch 213/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5649 - acc: 0.8707 - val_loss: 1.1325 - val_acc: 0.7083
#
# Epoch 00213: val_acc did not improve from 0.73611
# Epoch 214/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.6638 - acc: 0.8242 - val_loss: 1.2452 - val_acc: 0.6917
#
# Epoch 00214: val_acc did not improve from 0.73611
# Epoch 215/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.6291 - acc: 0.8353 - val_loss: 1.1673 - val_acc: 0.7028
#
# Epoch 00215: val_acc did not improve from 0.73611
#
# Epoch 00215: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 216/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5853 - acc: 0.8485 - val_loss: 1.1153 - val_acc: 0.7028
#
# Epoch 00216: val_acc did not improve from 0.73611
# Epoch 217/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5230 - acc: 0.8707 - val_loss: 1.1581 - val_acc: 0.6944
#
# Epoch 00217: val_acc did not improve from 0.73611
# Epoch 218/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4839 - acc: 0.8992 - val_loss: 1.1634 - val_acc: 0.7194
#
# Epoch 00218: val_acc did not improve from 0.73611
# Epoch 219/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4938 - acc: 0.8951 - val_loss: 1.1784 - val_acc: 0.6944
#
# Epoch 00219: val_acc did not improve from 0.73611
# Epoch 220/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4532 - acc: 0.9145 - val_loss: 1.1591 - val_acc: 0.7056
#
# Epoch 00220: val_acc did not improve from 0.73611
# Epoch 221/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4162 - acc: 0.9305 - val_loss: 1.0770 - val_acc: 0.7444
#
# Epoch 00221: val_acc improved from 0.73611 to 0.74444, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN+3LSTM_64_6_jester
# Epoch 222/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3967 - acc: 0.9430 - val_loss: 1.1968 - val_acc: 0.6667
#
# Epoch 00222: val_acc did not improve from 0.74444
# Epoch 223/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4012 - acc: 0.9451 - val_loss: 1.1221 - val_acc: 0.7278
#
# Epoch 00223: val_acc did not improve from 0.74444
# Epoch 224/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3942 - acc: 0.9507 - val_loss: 1.1411 - val_acc: 0.7250
#
# Epoch 00224: val_acc did not improve from 0.74444
# Epoch 225/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3866 - acc: 0.9444 - val_loss: 1.1520 - val_acc: 0.7278
#
# Epoch 00225: val_acc did not improve from 0.74444
#
# Epoch 00225: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 226/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3657 - acc: 0.9604 - val_loss: 1.1596 - val_acc: 0.7222
#
# Epoch 00226: val_acc did not improve from 0.74444
# Epoch 227/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3510 - acc: 0.9701 - val_loss: 1.2995 - val_acc: 0.6833
#
# Epoch 00227: val_acc did not improve from 0.74444
# Epoch 228/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3593 - acc: 0.9687 - val_loss: 1.1978 - val_acc: 0.7028
#
# Epoch 00228: val_acc did not improve from 0.74444
# Epoch 229/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3466 - acc: 0.9687 - val_loss: 1.2288 - val_acc: 0.7278
#
# Epoch 00229: val_acc did not improve from 0.74444
# Epoch 230/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3214 - acc: 0.9798 - val_loss: 1.2543 - val_acc: 0.7000
#
# Epoch 00230: val_acc did not improve from 0.74444
# Epoch 231/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3050 - acc: 0.9882 - val_loss: 1.2655 - val_acc: 0.7083
#
# Epoch 00231: val_acc did not improve from 0.74444
# Epoch 232/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2903 - acc: 0.9903 - val_loss: 1.2460 - val_acc: 0.7139
#
# Epoch 00232: val_acc did not improve from 0.74444
# Epoch 233/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3075 - acc: 0.9833 - val_loss: 1.3424 - val_acc: 0.7167
#
# Epoch 00233: val_acc did not improve from 0.74444
# Epoch 234/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4191 - acc: 0.9263 - val_loss: 1.3087 - val_acc: 0.7000
#
# Epoch 00234: val_acc did not improve from 0.74444
# Epoch 235/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5762 - acc: 0.8749 - val_loss: 1.3626 - val_acc: 0.6556
#
# Epoch 00235: val_acc did not improve from 0.74444
#
# Epoch 00235: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 236/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5458 - acc: 0.8749 - val_loss: 1.1608 - val_acc: 0.7111
#
# Epoch 00236: val_acc did not improve from 0.74444
# Epoch 237/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.6194 - acc: 0.8464 - val_loss: 1.2165 - val_acc: 0.6917
#
# Epoch 00237: val_acc did not improve from 0.74444
# Epoch 238/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.5144 - acc: 0.8881 - val_loss: 1.2450 - val_acc: 0.6917
#
# Epoch 00238: val_acc did not improve from 0.74444
# Epoch 239/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4331 - acc: 0.9201 - val_loss: 1.2207 - val_acc: 0.7167
#
# Epoch 00239: val_acc did not improve from 0.74444
# Epoch 240/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4341 - acc: 0.9180 - val_loss: 1.2199 - val_acc: 0.7194
#
# Epoch 00240: val_acc did not improve from 0.74444
# Epoch 241/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3834 - acc: 0.9527 - val_loss: 1.2512 - val_acc: 0.7028
#
# Epoch 00241: val_acc did not improve from 0.74444
# Epoch 242/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3800 - acc: 0.9472 - val_loss: 1.2705 - val_acc: 0.6944
#
# Epoch 00242: val_acc did not improve from 0.74444
# Epoch 243/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3780 - acc: 0.9486 - val_loss: 1.2252 - val_acc: 0.7111
#
# Epoch 00243: val_acc did not improve from 0.74444
# Epoch 244/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3557 - acc: 0.9590 - val_loss: 1.2523 - val_acc: 0.7083
#
# Epoch 00244: val_acc did not improve from 0.74444
# Epoch 245/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3152 - acc: 0.9743 - val_loss: 1.3057 - val_acc: 0.6889
#
# Epoch 00245: val_acc did not improve from 0.74444
#
# Epoch 00245: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 246/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3266 - acc: 0.9659 - val_loss: 1.3746 - val_acc: 0.6944
#
# Epoch 00246: val_acc did not improve from 0.74444
# Epoch 247/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4052 - acc: 0.9395 - val_loss: 1.2848 - val_acc: 0.7139
#
# Epoch 00247: val_acc did not improve from 0.74444
# Epoch 248/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3744 - acc: 0.9507 - val_loss: 1.2837 - val_acc: 0.7194
#
# Epoch 00248: val_acc did not improve from 0.74444
# Epoch 249/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3784 - acc: 0.9479 - val_loss: 1.2493 - val_acc: 0.7278
#
# Epoch 00249: val_acc did not improve from 0.74444
# Epoch 250/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3265 - acc: 0.9708 - val_loss: 1.2700 - val_acc: 0.7167
#
# Epoch 00250: val_acc did not improve from 0.74444
# Epoch 251/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3162 - acc: 0.9715 - val_loss: 1.3107 - val_acc: 0.7083
#
# Epoch 00251: val_acc did not improve from 0.74444
# Epoch 252/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3194 - acc: 0.9666 - val_loss: 1.4201 - val_acc: 0.6806
#
# Epoch 00252: val_acc did not improve from 0.74444
# Epoch 253/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3680 - acc: 0.9548 - val_loss: 1.2468 - val_acc: 0.7111
#
# Epoch 00253: val_acc did not improve from 0.74444
# Epoch 254/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3297 - acc: 0.9673 - val_loss: 1.2992 - val_acc: 0.7278
#
# Epoch 00254: val_acc did not improve from 0.74444
# Epoch 255/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3360 - acc: 0.9597 - val_loss: 1.3031 - val_acc: 0.7139
#
# Epoch 00255: val_acc did not improve from 0.74444
#
# Epoch 00255: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 256/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3385 - acc: 0.9639 - val_loss: 1.4400 - val_acc: 0.6861
#
# Epoch 00256: val_acc did not improve from 0.74444
# Epoch 257/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3605 - acc: 0.9521 - val_loss: 1.2446 - val_acc: 0.7250
#
# Epoch 00257: val_acc did not improve from 0.74444
# Epoch 258/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3171 - acc: 0.9750 - val_loss: 1.3276 - val_acc: 0.7278
#
# Epoch 00258: val_acc did not improve from 0.74444
# Epoch 259/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2988 - acc: 0.9792 - val_loss: 1.3290 - val_acc: 0.7111
#
# Epoch 00259: val_acc did not improve from 0.74444
# Epoch 260/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2979 - acc: 0.9764 - val_loss: 1.2705 - val_acc: 0.7333
#
# Epoch 00260: val_acc did not improve from 0.74444
# Epoch 261/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2706 - acc: 0.9910 - val_loss: 1.3026 - val_acc: 0.7389
#
# Epoch 00261: val_acc did not improve from 0.74444
# Epoch 262/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2636 - acc: 0.9937 - val_loss: 1.2903 - val_acc: 0.7389
#
# Epoch 00262: val_acc did not improve from 0.74444
# Epoch 263/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2976 - acc: 0.9785 - val_loss: 1.3960 - val_acc: 0.7083
#
# Epoch 00263: val_acc did not improve from 0.74444
# Epoch 264/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2847 - acc: 0.9798 - val_loss: 1.2875 - val_acc: 0.7389
#
# Epoch 00264: val_acc did not improve from 0.74444
# Epoch 265/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2770 - acc: 0.9854 - val_loss: 1.3524 - val_acc: 0.7167
#
# Epoch 00265: val_acc did not improve from 0.74444
#
# Epoch 00265: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 266/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2636 - acc: 0.9924 - val_loss: 1.4207 - val_acc: 0.7278
#
# Epoch 00266: val_acc did not improve from 0.74444
# Epoch 267/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2525 - acc: 0.9965 - val_loss: 1.3947 - val_acc: 0.7306
#
# Epoch 00267: val_acc did not improve from 0.74444
# Epoch 268/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2818 - acc: 0.9861 - val_loss: 1.5052 - val_acc: 0.6806
#
# Epoch 00268: val_acc did not improve from 0.74444
# Epoch 269/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3859 - acc: 0.9472 - val_loss: 1.5826 - val_acc: 0.6806
#
# Epoch 00269: val_acc did not improve from 0.74444
# Epoch 270/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4396 - acc: 0.9201 - val_loss: 1.4303 - val_acc: 0.7056
#
# Epoch 00270: val_acc did not improve from 0.74444
# Epoch 271/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.4408 - acc: 0.9208 - val_loss: 1.3050 - val_acc: 0.7139
#
# Epoch 00271: val_acc did not improve from 0.74444
# Epoch 272/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3553 - acc: 0.9548 - val_loss: 1.3835 - val_acc: 0.7056
#
# Epoch 00272: val_acc did not improve from 0.74444
# Epoch 273/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3338 - acc: 0.9632 - val_loss: 1.3436 - val_acc: 0.7139
#
# Epoch 00273: val_acc did not improve from 0.74444
# Epoch 274/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3208 - acc: 0.9736 - val_loss: 1.4726 - val_acc: 0.7111
#
# Epoch 00274: val_acc did not improve from 0.74444
# Epoch 275/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2880 - acc: 0.9771 - val_loss: 1.3979 - val_acc: 0.7306
#
# Epoch 00275: val_acc did not improve from 0.74444
#
# Epoch 00275: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 276/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.3134 - acc: 0.9708 - val_loss: 1.4554 - val_acc: 0.6833
#
# Epoch 00276: val_acc did not improve from 0.74444
# Epoch 277/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2990 - acc: 0.9778 - val_loss: 1.4946 - val_acc: 0.7056
#
# Epoch 00277: val_acc did not improve from 0.74444
# Epoch 278/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2549 - acc: 0.9965 - val_loss: 1.4172 - val_acc: 0.7417
#
# Epoch 00278: val_acc did not improve from 0.74444
# Epoch 279/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2443 - acc: 0.9979 - val_loss: 1.4656 - val_acc: 0.7139
#
# Epoch 00279: val_acc did not improve from 0.74444
# Epoch 280/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2402 - acc: 1.0000 - val_loss: 1.4734 - val_acc: 0.7250
#
# Epoch 00280: val_acc did not improve from 0.74444
# Epoch 281/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2378 - acc: 1.0000 - val_loss: 1.4588 - val_acc: 0.7333
#
# Epoch 00281: val_acc did not improve from 0.74444
# Epoch 282/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2351 - acc: 1.0000 - val_loss: 1.4631 - val_acc: 0.7278
#
# Epoch 00282: val_acc did not improve from 0.74444
# Epoch 283/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2339 - acc: 1.0000 - val_loss: 1.4730 - val_acc: 0.7250
#
# Epoch 00283: val_acc did not improve from 0.74444
# Epoch 284/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2348 - acc: 1.0000 - val_loss: 1.4782 - val_acc: 0.7333
#
# Epoch 00284: val_acc did not improve from 0.74444
# Epoch 285/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2344 - acc: 1.0000 - val_loss: 1.4850 - val_acc: 0.7306
#
# Epoch 00285: val_acc did not improve from 0.74444
#
# Epoch 00285: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 286/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2321 - acc: 1.0000 - val_loss: 1.4898 - val_acc: 0.7250
#
# Epoch 00286: val_acc did not improve from 0.74444
# Epoch 287/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2325 - acc: 1.0000 - val_loss: 1.4966 - val_acc: 0.7250
#
# Epoch 00287: val_acc did not improve from 0.74444
# Epoch 288/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2324 - acc: 1.0000 - val_loss: 1.5054 - val_acc: 0.7222
#
# Epoch 00288: val_acc did not improve from 0.74444
# Epoch 289/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2316 - acc: 1.0000 - val_loss: 1.5158 - val_acc: 0.7194
#
# Epoch 00289: val_acc did not improve from 0.74444
# Epoch 290/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2323 - acc: 1.0000 - val_loss: 1.5232 - val_acc: 0.7194
#
# Epoch 00290: val_acc did not improve from 0.74444
# Epoch 291/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2320 - acc: 0.9993 - val_loss: 1.5318 - val_acc: 0.7167
#
# Epoch 00291: val_acc did not improve from 0.74444
# Epoch 292/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2302 - acc: 1.0000 - val_loss: 1.5420 - val_acc: 0.7167
#
# Epoch 00292: val_acc did not improve from 0.74444
# Epoch 293/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2304 - acc: 1.0000 - val_loss: 1.5403 - val_acc: 0.7222
#
# Epoch 00293: val_acc did not improve from 0.74444
# Epoch 294/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2317 - acc: 1.0000 - val_loss: 1.5477 - val_acc: 0.7250
#
# Epoch 00294: val_acc did not improve from 0.74444
# Epoch 295/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2296 - acc: 1.0000 - val_loss: 1.5517 - val_acc: 0.7250
#
# Epoch 00295: val_acc did not improve from 0.74444
#
# Epoch 00295: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 296/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2301 - acc: 1.0000 - val_loss: 1.5524 - val_acc: 0.7250
#
# Epoch 00296: val_acc did not improve from 0.74444
# Epoch 297/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2294 - acc: 1.0000 - val_loss: 1.5562 - val_acc: 0.7306
#
# Epoch 00297: val_acc did not improve from 0.74444
# Epoch 298/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2302 - acc: 1.0000 - val_loss: 1.5657 - val_acc: 0.7250
#
# Epoch 00298: val_acc did not improve from 0.74444
# Epoch 299/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2291 - acc: 1.0000 - val_loss: 1.5728 - val_acc: 0.7222
#
# Epoch 00299: val_acc did not improve from 0.74444
# Epoch 300/300
# 1439/1439 [==============================] - 8s 6ms/step - loss: 0.2286 - acc: 1.0000 - val_loss: 1.5763 - val_acc: 0.7222
#
# Epoch 00300: val_acc did not improve from 0.74444

# %%
training_loss = hist.history['loss']
val_loss = hist.history['val_loss']

plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
training_acc = hist.history['acc']
val_acc = hist.history['val_acc']

plt.plot(training_acc, label="training_accuracy")
plt.plot(val_acc, label="validation_accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
from keras.models import Model, load_model
model1_name = "3DCNN+3LSTM_64_6_jester"
model1_path = os.path.join(save_dir, model1_name)
model1 = load_model(model1_path)

# %%
test_pred =model1.predict(X_train_new[50:70])
result = np.argmax(test_pred, axis =1)
print(result)
# Out:
# [1 2 3 1 1 1 4 0 2 1 1 3 1 4 4 2 4 4 0 0]

# %%
img_array = X_train_new[50]

# %%
plt.imshow(img_array[0,:,:,9])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-b36be9350f5a> in <module>()
#       1
# ----> 2 plt.imshow(img_array[0,:,:,9])
#
# IndexError: index 9 is out of bounds for axis 3 with size 3

# %%
#np.argmax(y_val_new[0:20],axis =1)

# %%
from sklearn.metrics import confusion_matrix
met = confusion_matrix(np.argmax(y_val_new,axis =1), np.argmax(model1.predict(X_val_new),axis =1))
print(met)
# Out:
# [[38 21  0  0  1  0]
#  [26 38  3  0  3  1]
#  [ 1  3 42  2  2  6]
#  [ 1  0  4 42  2  4]
#  [ 3  0  1  2 55  1]
#  [ 0  0  4  0  1 53]]

# %%
import itertools
def confusion_matrix_plot(cm, classes, 
                          title='Normalized Confusion Matrix', 
                          normalize=True, 
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    plt.subplots(1, 1, figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
confusion_matrix_plot(met, classes=['Backward', 'Forward', 'Stop', 'Swiping Left', 'Swiping Right','No Gesture'])

# %%
from keras.models import Model, load_model
model2_name = "3DCNN+2LSTM_64_6_jester_2"
model2_path = os.path.join(save_dir, model2_name)
model2 = load_model(model2_path)

# %%
met = confusion_matrix(np.argmax(y_val_new,axis =1), np.argmax(model2.predict(X_val_new),axis =1))
print(met)
# Out:
# [[32 24  2  0  2  0]
#  [16 46  1  1  6  1]
#  [ 0  1 44  3  2  6]
#  [ 1  0  1 47  1  3]
#  [ 1  0  3  2 56  0]
#  [ 0  1  3  0  1 53]]

# %%
model2.evaluate(X_val_new,y_val_new)
# Out:
# 360/360 [==============================] - 1s 3ms/step
# [0.8546751605139838, 0.7472222222222222]

# %%
for i in range(10):
    we=(i+1)/10
    we_2=1-we
    met = confusion_matrix(np.argmax(y_val_new,axis =1), np.argmax(we*model2.predict(X_val_new)+we_2*model1.predict(X_val_new),axis =1))
    print((met[0,0]+met[1,1]+met[2,2]+met[3,3]+met[4,4]+met[5,5])/360)
# Out:
# 0.7416666666666667
# 0.7472222222222222
# 0.7472222222222222
# 0.7416666666666667
# 0.7527777777777778
# 0.7444444444444445
# 0.7583333333333333
# 0.7611111111111111
# 0.7666666666666667
# 0.7722222222222223
