# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers.convolutional import Conv3D, MaxPooling3D,Conv2D,AveragePooling2D,AveragePooling3D
from keras.layers import Dense, GlobalAveragePooling3D,GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler,ReduceLROnPlateau
from keras.optimizers import SGD, RMSprop, Adadelta
from keras.utils import np_utils, generic_utils
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional_recurrent import ConvLSTM2D

import theano
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.cross_validation import train_test_split
from sklearn import cross_validation
from sklearn import preprocessing
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /opt/conda/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# image specification
img_rows,img_cols=125, 57 

# Training data

X_tr=[]           # variable to store entire dataset

# %%
'''
import os
from tqdm import tqdm
ls_path_10 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/")
listing_10 = os.listdir(ls_path_10)
for ls_1 in listing_10:
    ls_path_11 = os.path.join(ls_path_10,ls_1)
    listing_11 = os.listdir(ls_path_11)
    for ls in tqdm(listing_11):
        listing_stop_10 = os.listdir(os.path.join(ls_path_11,ls)) 
        #print(ls)
        img_depth = len(listing_stop_10)
        if img_depth < 20:
            print(img_depth)
            print(ls)
'''
# Out:
# '\nimport os\nfrom tqdm import tqdm\nls_path_10 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/")\nlisting_10 = os.listdir(ls_path_10)\nfor ls_1 in listing_10:\n    ls_path_11 = os.path.join(ls_path_10,ls_1)\n    listing_11 = os.listdir(ls_path_11)\n    for ls in tqdm(listing_11):\n        listing_stop_10 = os.listdir(os.path.join(ls_path_11,ls)) \n        #print(ls)\n        img_depth = len(listing_stop_10)\n        if img_depth < 20:\n            print(img_depth)\n            print(ls)\n'

# %%
from tqdm import tqdm

ls_path = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Rolling Hand Backward")
listing = os.listdir(ls_path)

for ls in tqdm(listing):
    listing_stop = sorted(os.listdir(os.path.join(ls_path,ls))) 
    #print(ls)
    #img_depth = len(listing_stop)
    #if img_depth < 15:
        #print(img_depth)
        #print(ls)
    frames = []
    img_depth=0
    for imgs in listing_stop:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path,ls),imgs)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #print(frame.shape)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #print(frame.shape)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 83.58it/s]
# (16, 57, 125, 3)
# 300

# %%
from tqdm import tqdm

ls_path_2 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Rolling Hand Forward")
listing_2 = os.listdir(ls_path_2)

for ls_2 in tqdm(listing_2):
    listing_stop_2 = sorted(os.listdir(os.path.join(ls_path_2,ls_2)))
    #print(ls_2)
    #img_depth = len(listing_stop_2)
    #print(img_depth)
    frames = []
    img_depth= 0
    for imgs_2 in listing_stop_2:
        if img_depth < 16:
            img = os.path.join(os.path.join(ls_path_2,ls_2),imgs_2)
            #ret, frame = cap.read()
            #print(img)
            frame = cv2.imread(img)
            #print(imgs_2)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 84.40it/s]
# (16, 57, 125, 3)
# 600

# %%
from tqdm import tqdm

ls_path_3 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Stop")
listing_3 = os.listdir(ls_path_3)

for ls_3 in tqdm(listing_3):
    listing_stop_3 = sorted(os.listdir(os.path.join(ls_path_3,ls_3)))
    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_3 in listing_stop_3:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_3,ls_3),imgs_3)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 85.03it/s]
# (16, 57, 125, 3)
# 900

# %%
from tqdm import tqdm

ls_path_4 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Swiping Left")
listing_4 = os.listdir(ls_path_4)

for ls_4 in tqdm(listing_4):
    listing_stop_4 = sorted(os.listdir(os.path.join(ls_path_4,ls_4)))

    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_4 in listing_stop_4:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_4,ls_4),imgs_4)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 299/299 [00:03<00:00, 83.42it/s]
# (16, 57, 125, 3)
# 1199

# %%
print(ls_4)
# Out:
# 7380

# %%
from tqdm import tqdm

ls_path_5 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/Swiping Right")
listing_5 = os.listdir(ls_path_5)

for ls_5 in tqdm(listing_5):
    listing_stop_5 = sorted(os.listdir(os.path.join(ls_path_5,ls_5)))

    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_5 in listing_stop_5:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_5,ls_5),imgs_5)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 85.02it/s]
# (16, 57, 125, 3)
# 1499

# %%
from tqdm import tqdm

ls_path_6 = os.path.join("//home/jovyan/program/project/3DCNN/resnet/jester/No gesture")
listing_6 = os.listdir(ls_path_6)

for ls_6 in tqdm(listing_6):
    listing_stop_6 = sorted(os.listdir(os.path.join(ls_path_6,ls_6)))
    #print(ls)
    #img_depth = len(listing_stop_3)
    frames = []
    img_depth=0
    for imgs_6 in listing_stop_6:
        if img_depth <16:
            img = os.path.join(os.path.join(ls_path_6,ls_6),imgs_6)
            #ret, frame = cap.read()
            frame = cv2.imread(img)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            frame=cv2.resize(frame,(img_rows,img_cols),interpolation=cv2.INTER_AREA)
            #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(gray)
            img_depth=img_depth+1
        else:
            break
    input_img = np.array(frames)
    #print (input_img.shape)
    ipt=np.rollaxis(np.rollaxis(input_img,2,0),2,0)
    ipt=np.rollaxis(ipt,2,0)
    #print (ipt.shape)
    X_tr.append(ipt)

#X_tr_array = np.array(X_tr)   # convert the frames read into array
print (ipt.shape)
num_samples = len(X_tr) 
print (num_samples)
# Out:
# 100%|██████████| 300/300 [00:03<00:00, 83.73it/s]
# (16, 57, 125, 3)
# 1799

# %%
X_tr_array = np.array(X_tr)   # convert the frames read into array

num_samples = len(X_tr_array) 
print (num_samples)
# Out:
# 1799

# %%
'''
label=np.ones((num_samples,),dtype = int)
label[0:74]= 0
label[75:136] = 1
'''
# Out:
# '\nlabel=np.ones((num_samples,),dtype = int)\nlabel[0:74]= 0\nlabel[75:136] = 1\n'

# %%
label=np.ones((num_samples,),dtype = int)
label[0:300]= 0
label[300:600] = 1
label[600:900] = 2
label[900:1199] = 3
label[1199:1499] = 4
label[1499:1799] = 5

# %%
img_depth = 16
train_data = [X_tr_array,label]

(X_train, y_train) = (train_data[0],train_data[1])
print('X_Train shape:', X_train.shape)

train_set = np.zeros((num_samples, img_depth, img_cols,img_rows,3))

for h in range(num_samples):
    train_set[h][:][:][:][:]=X_train[h,:,:,:]
  

patch_size = 16    # img_depth or number of frames used for each video

print(train_set.shape, 'train samples')
# Out:
# X_Train shape: (1799, 16, 57, 125, 3)
# (1799, 16, 57, 125, 3) train samples

# %%
# CNN Training parameters


nb_classes = 6

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)

# %%
# Pre-processing

train_set = train_set.astype('float32')
print(np.mean(train_set))
train_set -= np.mean(train_set)
print(np.max(train_set))
train_set /=np.max(train_set)
# Out:
# 108.013306
# 146.9867

# %%
#low resolution network
weight_decay = 0.005
from keras import regularizers
model = Sequential()
model.add(MaxPooling3D(pool_size=(1, 2, 2),input_shape=(patch_size, 57, 125, 3)))

model.add(Conv3D(8,(5,5,5),activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(32,(3,5,5), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(64,(3,3,5), activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(MaxPooling3D(pool_size=(1, 1, 4 )))



#model.add(Conv3D(128,3,3,3, activation='relu'))
#model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2),
#border_mode='valid'))
#model.add(BatchNormalization())

model.add(Flatten())
#model.add(GlobalAveragePooling3D())
model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Dropout(0.5))

model.add(Dense(nb_classes,kernel_initializer='normal',kernel_regularizer=regularizers.l2(weight_decay)))

model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# max_pooling3d_1 (MaxPooling3 (None, 16, 28, 62, 3)     0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 12, 24, 58, 8)     3008
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 12, 12, 29, 8)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 10, 8, 25, 32)     19232
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 5, 4, 12, 32)      0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 3, 2, 8, 64)       92224
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 3, 2, 2, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 1542
# _________________________________________________________________
# activation_1 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 641,062
# Trainable params: 641,062
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
#os.chdir('///home/jovyan/program/DL/11_1下tensorflow_simpson')
save_dir = os.path.join(os.getcwd(),'saved_model')
print(os.getcwd())
model_name = "3DCNN_LRN_112_6_jester"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor = 'val_acc', 
                            save_best_only=True, verbose=1)
#earlystop
earlystop = EarlyStopping(monitor='val_loss', patience=50, verbose =1)
# Out:
# /home/jovyan/program/project/3DCNN

# %%
sgd = SGD(lr=0.005,  momentum=0.9, nesterov=False)
rms = RMSprop(decay=1e-6)
ada = Adadelta(lr=0.1,decay=1e-6)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              #optimizer=ada,
              metrics=['acc'])
# Split the data

# %%
X_train_new, X_val_new, y_train_new,y_val_new = train_test_split(train_set, Y_train, test_size=0.2, random_state=20)

# %%
batch_size = 32
nb_epoch =200
#steps_per_epoch=int((len(X_val_new)*1.5)/batch_size)
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.05, 
                               cooldown=0, patience=10, min_lr=0.005/(2^4),verbose=1)
hist = model.fit(
    X_train_new,
    y_train_new,
    validation_data=(X_val_new,y_val_new),
    batch_size=batch_size,
    epochs = nb_epoch,
    shuffle=True,
    callbacks=[checkpoint,lr_reducer]
    )
# Out:
# Train on 1439 samples, validate on 360 samples
# Epoch 1/200
# 1439/1439 [==============================] - 8s 6ms/step - loss: 6.8253 - acc: 0.1640 - val_loss: 6.7173 - val_acc: 0.1694
#
# Epoch 00001: val_acc improved from -inf to 0.16944, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 2/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 6.6081 - acc: 0.1786 - val_loss: 6.4992 - val_acc: 0.1556
#
# Epoch 00002: val_acc did not improve from 0.16944
# Epoch 3/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 6.3936 - acc: 0.1647 - val_loss: 6.2904 - val_acc: 0.1667
#
# Epoch 00003: val_acc did not improve from 0.16944
# Epoch 4/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 6.1903 - acc: 0.1821 - val_loss: 6.0928 - val_acc: 0.1694
#
# Epoch 00004: val_acc did not improve from 0.16944
# Epoch 5/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 5.9976 - acc: 0.1591 - val_loss: 5.9015 - val_acc: 0.1861
#
# Epoch 00005: val_acc improved from 0.16944 to 0.18611, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 6/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 5.8104 - acc: 0.1765 - val_loss: 5.7191 - val_acc: 0.1667
#
# Epoch 00006: val_acc did not improve from 0.18611
# Epoch 7/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 5.6322 - acc: 0.1946 - val_loss: 5.5460 - val_acc: 0.1750
#
# Epoch 00007: val_acc did not improve from 0.18611
# Epoch 8/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 5.4625 - acc: 0.1890 - val_loss: 5.3784 - val_acc: 0.1889
#
# Epoch 00008: val_acc improved from 0.18611 to 0.18889, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 9/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 5.2971 - acc: 0.1953 - val_loss: 5.2198 - val_acc: 0.1750
#
# Epoch 00009: val_acc did not improve from 0.18889
# Epoch 10/200
# 1439/1439 [==============================] - 5s 3ms/step - loss:
200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 2.3397 - acc: 0.7054 - val_loss: 2.5050 - val_acc: 0.6917
#
# Epoch 00029: val_acc improved from 0.68889 to 0.69167, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 30/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 2.2082 - acc: 0.7213 - val_loss: 2.4830 - val_acc: 0.6750
#
# Epoch 00030: val_acc did not improve from 0.69167
# Epoch 31/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 2.1418 - acc: 0.7352 - val_loss: 2.4557 - val_acc: 0.6806
#
# Epoch 00031: val_acc did not improve from 0.69167
# Epoch 32/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 2.0886 - acc: 0.7311 - val_loss: 2.3855 - val_acc: 0.6556
#
# Epoch 00032: val_acc did not improve from 0.69167
# Epoch 33/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.9973 - acc: 0.7436 - val_loss: 2.2975 - val_acc: 0.6694
#
# Epoch 00033: val_acc did not improve from 0.69167
# Epoch 34/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.9621 - acc: 0.7464 - val_loss: 2.3907 - val_acc: 0.6222
#
# Epoch 00034: val_acc did not improve from 0.69167
# Epoch 35/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 1.8883 - acc: 0.7443 - val_loss: 2.1295 - val_acc: 0.6972
#
# Epoch 00035: val_acc improved from 0.69167 to 0.69722, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 36/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.8245 - acc: 0.7596 - val_loss: 2.1518 - val_acc: 0.6750
#
# Epoch 00036: val_acc did not improve from 0.69722
# Epoch 37/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.7747 - acc: 0.7623 - val_loss: 2.2298 - val_acc: 0.6472
#
# Epoch 00037: val_acc did not improve from 0.69722
# Epoch 38/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.7164 - acc: 0.7596 - val_loss: 2.1942 - val_acc: 0.6750
#
# Epoch 00038: val_acc did not improve from 0.69722
# Epoch 39/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.6411 - acc: 0.7880 - val_loss: 2.0421 - val_acc: 0.6861
#
# Epoch 00039: val_acc did not improve from 0.69722
# Epoch 40/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.5951 - acc: 0.7936 - val_loss: 1.9725 - val_acc: 0.6806
#
# Epoch 00040: val_acc did not improve from 0.69722
# Epoch 41/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.5972 - acc: 0.7762 - val_loss: 2.0324 - val_acc: 0.6556
#
# Epoch 00041: val_acc did not improve from 0.69722
# Epoch 42/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 1.5860 - acc: 0.7776 - val_loss: 1.9255 - val_acc: 0.6833
#
# Epoch 00042: val_acc did not improve from 0.69722
# Epoch 43/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 1.4696 - acc: 0.8026 - val_loss: 2.0304 - val_acc: 0.6861
#
# Epoch 00043: val_acc did not improve from 0.69722
# Epoch 44/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.4498 - acc: 0.8117 - val_loss: 1.9734 - val_acc: 0.6667
#
# Epoch 00044: val_acc did not improve from 0.69722
# Epoch 45/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.4327 - acc: 0.8068 - val_loss: 1.8632 - val_acc: 0.6806
#
# Epoch 00045: val_acc did not improve from 0.69722
# Epoch 46/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.3493 - acc: 0.8360 - val_loss: 1.9582 - val_acc: 0.6861
#
# Epoch 00046: val_acc did not improve from 0.69722
# Epoch 47/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.3421 - acc: 0.8235 - val_loss: 1.9890 - val_acc: 0.6611
#
# Epoch 00047: val_acc did not improve from 0.69722
# Epoch 48/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.2627 - acc: 0.8374 - val_loss: 1.8832 - val_acc: 0.7000
#
# Epoch 00048: val_acc improved from 0.69722 to 0.70000, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 49/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.2673 - acc: 0.8423 - val_loss: 1.8085 - val_acc: 0.7000
#
# Epoch 00049: val_acc did not improve from 0.70000
# Epoch 50/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 1.2278 - acc: 0.8520 - val_loss: 1.8370 - val_acc: 0.6889
#
# Epoch 00050: val_acc did not improve from 0.70000
# Epoch 51/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.1701 - acc: 0.8659 - val_loss: 1.8802 - val_acc: 0.7000
#
# Epoch 00051: val_acc did not improve from 0.70000
# Epoch 52/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.1344 - acc: 0.8638 - val_loss: 1.9367 - val_acc: 0.6972
#
# Epoch 00052: val_acc did not improve from 0.70000
# Epoch 53/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 1.1137 - acc: 0.8763 - val_loss: 1.9971 - val_acc: 0.6333
#
# Epoch 00053: val_acc did not improve from 0.70000
# Epoch 54/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.1928 - acc: 0.8284 - val_loss: 1.7428 - val_acc: 0.6972
#
# Epoch 00054: val_acc did not improve from 0.70000
# Epoch 55/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.0715 - acc: 0.8846 - val_loss: 1.8193 - val_acc: 0.6722
#
# Epoch 00055: val_acc did not improve from 0.70000
# Epoch 56/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.0199 - acc: 0.8930 - val_loss: 2.0392 - val_acc: 0.6917
#
# Epoch 00056: val_acc did not improve from 0.70000
# Epoch 57/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.0181 - acc: 0.8881 - val_loss: 1.8209 - val_acc: 0.6611
#
# Epoch 00057: val_acc did not improve from 0.70000
# Epoch 58/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.9784 - acc: 0.9013 - val_loss: 1.9037 - val_acc: 0.6861
#
# Epoch 00058: val_acc did not improve from 0.70000
# Epoch 59/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 1.0239 - acc: 0.8714 - val_loss: 1.7821 - val_acc: 0.6778
#
# Epoch 00059: val_acc did not improve from 0.70000
# Epoch 60/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.9588 - acc: 0.8985 - val_loss: 1.9658 - val_acc: 0.6944
#
# Epoch 00060: val_acc did not improve from 0.70000
# Epoch 61/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.9164 - acc: 0.9152 - val_loss: 1.9073 - val_acc: 0.6806
#
# Epoch 00061: val_acc did not improve from 0.70000
# Epoch 62/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.9285 - acc: 0.9097 - val_loss: 2.0338 - val_acc: 0.6806
#
# Epoch 00062: val_acc did not improve from 0.70000
# Epoch 63/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.9438 - acc: 0.8958 - val_loss: 2.0454 - val_acc: 0.6639
#
# Epoch 00063: val_acc did not improve from 0.70000
# Epoch 64/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 1.0108 - acc: 0.8756 - val_loss: 1.7821 - val_acc: 0.6861
#
# Epoch 00064: val_acc did not improve from 0.70000
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 65/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.8992 - acc: 0.9069 - val_loss: 1.7997 - val_acc: 0.6917
#
# Epoch 00065: val_acc did not improve from 0.70000
# Epoch 66/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.8094 - acc: 0.9527 - val_loss: 1.8186 - val_acc: 0.6861
#
# Epoch 00066: val_acc did not improve from 0.70000
# Epoch 67/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.7828 - acc: 0.9583 - val_loss: 1.8901 - val_acc: 0.6889
#
# Epoch 00067: val_acc did not improve from 0.70000
# Epoch 68/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.7633 - acc: 0.9618 - val_loss: 1.8886 - val_acc: 0.6861
#
# Epoch 00068: val_acc did not improve from 0.70000
# Epoch 69/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.7513 - acc: 0.9659 - val_loss: 1.8999 - val_acc: 0.7000
#
# Epoch 00069: val_acc did not improve from 0.70000
# Epoch 70/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.7435 - acc: 0.9666 - val_loss: 1.9688 - val_acc: 0.6889
#
# Epoch 00070: val_acc did not improve from 0.70000
# Epoch 71/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.7330 - acc: 0.9743 - val_loss: 1.9682 - val_acc: 0.6944
#
# Epoch 00071: val_acc did not improve from 0.70000
# Epoch 72/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.7185 - acc: 0.9778 - val_loss: 2.0011 - val_acc: 0.6972
#
# Epoch 00072: val_acc did not improve from 0.70000
# Epoch 73/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.7096 - acc: 0.9792 - val_loss: 2.0116 - val_acc: 0.7028
#
# Epoch 00073: val_acc improved from 0.70000 to 0.70278, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 74/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.7047 - acc: 0.9805 - val_loss: 2.0285 - val_acc: 0.6917
#
# Epoch 00074: val_acc did not improve from 0.70278
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 75/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6975 - acc: 0.9792 - val_loss: 2.0291 - val_acc: 0.6972
#
# Epoch 00075: val_acc did not improve from 0.70278
# Epoch 76/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6943 - acc: 0.9785 - val_loss: 2.0157 - val_acc: 0.6917
#
# Epoch 00076: val_acc did not improve from 0.70278
# Epoch 77/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6847 - acc: 0.9833 - val_loss: 2.0454 - val_acc: 0.7083
#
# Epoch 00077: val_acc improved from 0.70278 to 0.70833, saving model to /home/jovyan/program/project/3DCNN/saved_model/3DCNN_LRN_112_6_jester
# Epoch 78/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.6810 - acc: 0.9778 - val_loss: 2.0651 - val_acc: 0.6917
#
# Epoch 00078: val_acc did not improve from 0.70833
# Epoch 79/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.6769 - acc: 0.9833 - val_loss: 2.1185 - val_acc: 0.6806
#
# Epoch 00079: val_acc did not improve from 0.70833
# Epoch 80/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6660 - acc: 0.9875 - val_loss: 2.0732 - val_acc: 0.6944
#
# Epoch 00080: val_acc did not improve from 0.70833
# Epoch 81/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6626 - acc: 0.9896 - val_loss: 2.1136 - val_acc: 0.6972
#
# Epoch 00081: val_acc did not improve from 0.70833
# Epoch 82/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6613 - acc: 0.9875 - val_loss: 2.1387 - val_acc: 0.7000
#
# Epoch 00082: val_acc did not improve from 0.70833
# Epoch 83/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6553 - acc: 0.9889 - val_loss: 2.1113 - val_acc: 0.6972
#
# Epoch 00083: val_acc did not improve from 0.70833
# Epoch 84/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.6514 - acc: 0.9889 - val_loss: 2.0926 - val_acc: 0.6889
#
# Epoch 00084: val_acc did not improve from 0.70833
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 85/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6429 - acc: 0.9903 - val_loss: 2.1262 - val_acc: 0.6917
#
# Epoch 00085: val_acc did not improve from 0.70833
# Epoch 86/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.6418 - acc: 0.9896 - val_loss: 2.1546 - val_acc: 0.6806
#
# Epoch 00086: val_acc did not improve from 0.70833
# Epoch 87/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6397 - acc: 0.9882 - val_loss: 2.2019 - val_acc: 0.6778
#
# Epoch 00087: val_acc did not improve from 0.70833
# Epoch 88/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6400 - acc: 0.9896 - val_loss: 2.1193 - val_acc: 0.6972
#
# Epoch 00088: val_acc did not improve from 0.70833
# Epoch 89/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.6266 - acc: 0.9903 - val_loss: 2.1666 - val_acc: 0.6778
#
# Epoch 00089: val_acc did not improve from 0.70833
# Epoch 90/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.6251 - acc: 0.9889 - val_loss: 2.1468 - val_acc: 0.6889
#
# Epoch 00090: val_acc did not improve from 0.70833
# Epoch 91/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.
200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5565 - acc: 0.9979 - val_loss: 2.2072 - val_acc: 0.6778
#
# Epoch 00111: val_acc did not improve from 0.70833
# Epoch 112/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.5566 - acc: 0.9965 - val_loss: 2.2427 - val_acc: 0.6750
#
# Epoch 00112: val_acc did not improve from 0.70833
# Epoch 113/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.5503 - acc: 0.9965 - val_loss: 2.2260 - val_acc: 0.6861
#
# Epoch 00113: val_acc did not improve from 0.70833
# Epoch 114/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.5471 - acc: 0.9972 - val_loss: 2.2160 - val_acc: 0.6722
#
# Epoch 00114: val_acc did not improve from 0.70833
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 115/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5467 - acc: 0.9944 - val_loss: 2.1750 - val_acc: 0.6889
#
# Epoch 00115: val_acc did not improve from 0.70833
# Epoch 116/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5453 - acc: 0.9958 - val_loss: 2.1486 - val_acc: 0.6861
#
# Epoch 00116: val_acc did not improve from 0.70833
# Epoch 117/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5438 - acc: 0.9972 - val_loss: 2.1835 - val_acc: 0.6806
#
# Epoch 00117: val_acc did not improve from 0.70833
# Epoch 118/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5507 - acc: 0.9917 - val_loss: 2.1445 - val_acc: 0.6778
#
# Epoch 00118: val_acc did not improve from 0.70833
# Epoch 119/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.5396 - acc: 0.9965 - val_loss: 2.1955 - val_acc: 0.6667
#
# Epoch 00119: val_acc did not improve from 0.70833
# Epoch 120/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.5328 - acc: 0.9965 - val_loss: 2.1477 - val_acc: 0.6722
#
# Epoch 00120: val_acc did not improve from 0.70833
# Epoch 121/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5325 - acc: 0.9958 - val_loss: 2.1538 - val_acc: 0.6750
#
# Epoch 00121: val_acc did not improve from 0.70833
# Epoch 122/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5319 - acc: 0.9958 - val_loss: 2.1614 - val_acc: 0.6778
#
# Epoch 00122: val_acc did not improve from 0.70833
# Epoch 123/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5285 - acc: 0.9972 - val_loss: 2.1993 - val_acc: 0.6667
#
# Epoch 00123: val_acc did not improve from 0.70833
# Epoch 124/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5231 - acc: 0.9979 - val_loss: 2.1944 - val_acc: 0.6833
#
# Epoch 00124: val_acc did not improve from 0.70833
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 125/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5233 - acc: 0.9972 - val_loss: 2.2325 - val_acc: 0.6694
#
# Epoch 00125: val_acc did not improve from 0.70833
# Epoch 126/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5205 - acc: 0.9951 - val_loss: 2.1536 - val_acc: 0.6722
#
# Epoch 00126: val_acc did not improve from 0.70833
# Epoch 127/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.5191 - acc: 0.9958 - val_loss: 2.1291 - val_acc: 0.6861
#
# Epoch 00127: val_acc did not improve from 0.70833
# Epoch 128/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5199 - acc: 0.9958 - val_loss: 2.1967 - val_acc: 0.6833
#
# Epoch 00128: val_acc did not improve from 0.70833
# Epoch 129/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5160 - acc: 0.9979 - val_loss: 2.1734 - val_acc: 0.6778
#
# Epoch 00129: val_acc did not improve from 0.70833
# Epoch 130/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5134 - acc: 0.9972 - val_loss: 2.2351 - val_acc: 0.6806
#
# Epoch 00130: val_acc did not improve from 0.70833
# Epoch 131/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.5164 - acc: 0.9958 - val_loss: 2.1418 - val_acc: 0.6778
#
# Epoch 00131: val_acc did not improve from 0.70833
# Epoch 132/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.
200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4306 - acc: 0.9979 - val_loss: 2.1202 - val_acc: 0.6639
#
# Epoch 00173: val_acc did not improve from 0.70833
# Epoch 174/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4289 - acc: 0.9979 - val_loss: 2.0920 - val_acc: 0.6639
#
# Epoch 00174: val_acc did not improve from 0.70833
#
# Epoch 00174: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 175/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4300 - acc: 0.9979 - val_loss: 2.0903 - val_acc: 0.6611
#
# Epoch 00175: val_acc did not improve from 0.70833
# Epoch 176/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4292 - acc: 0.9972 - val_loss: 2.0348 - val_acc: 0.6694
#
# Epoch 00176: val_acc did not improve from 0.70833
# Epoch 177/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4272 - acc: 0.9993 - val_loss: 2.0759 - val_acc: 0.6667
#
# Epoch 00177: val_acc did not improve from 0.70833
# Epoch 178/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4270 - acc: 0.9979 - val_loss: 2.0822 - val_acc: 0.6667
#
# Epoch 00178: val_acc did not improve from 0.70833
# Epoch 179/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4261 - acc: 0.9972 - val_loss: 2.1399 - val_acc: 0.6639
#
# Epoch 00179: val_acc did not improve from 0.70833
# Epoch 180/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4226 - acc: 0.9972 - val_loss: 2.0430 - val_acc: 0.6583
#
# Epoch 00180: val_acc did not improve from 0.70833
# Epoch 181/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4233 - acc: 0.9993 - val_loss: 2.0789 - val_acc: 0.6583
#
# Epoch 00181: val_acc did not improve from 0.70833
# Epoch 182/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4190 - acc: 0.9986 - val_loss: 2.0762 - val_acc: 0.6667
#
# Epoch 00182: val_acc did not improve from 0.70833
# Epoch 183/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4189 - acc: 0.9958 - val_loss: 2.0348 - val_acc: 0.6528
#
# Epoch 00183: val_acc did not improve from 0.70833
# Epoch 184/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4179 - acc: 0.9979 - val_loss: 2.0329 - val_acc: 0.6694
#
# Epoch 00184: val_acc did not improve from 0.70833
#
# Epoch 00184: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 185/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4136 - acc: 0.9979 - val_loss: 2.0341 - val_acc: 0.6611
#
# Epoch 00185: val_acc did not improve from 0.70833
# Epoch 186/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4121 - acc: 1.0000 - val_loss: 2.0890 - val_acc: 0.6528
#
# Epoch 00186: val_acc did not improve from 0.70833
# Epoch 187/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4139 - acc: 0.9972 - val_loss: 2.0375 - val_acc: 0.6583
#
# Epoch 00187: val_acc did not improve from 0.70833
# Epoch 188/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4109 - acc: 0.9979 - val_loss: 2.0459 - val_acc: 0.6611
#
# Epoch 00188: val_acc did not improve from 0.70833
# Epoch 189/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4076 - acc: 0.9986 - val_loss: 1.9742 - val_acc: 0.6722
#
# Epoch 00189: val_acc did not improve from 0.70833
# Epoch 190/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4092 - acc: 0.9986 - val_loss: 2.1371 - val_acc: 0.6528
#
# Epoch 00190: val_acc did not improve from 0.70833
# Epoch 191/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4065 - acc: 0.9979 - val_loss: 2.0494 - val_acc: 0.6722
#
# Epoch 00191: val_acc did not improve from 0.70833
# Epoch 192/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4124 - acc: 0.9979 - val_loss: 2.0343 - val_acc: 0.6667
#
# Epoch 00192: val_acc did not improve from 0.70833
# Epoch 193/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4030 - acc: 0.9986 - val_loss: 2.0088 - val_acc: 0.6639
#
# Epoch 00193: val_acc did not improve from 0.70833
# Epoch 194/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4023 - acc: 0.9979 - val_loss: 2.0653 - val_acc: 0.6694
#
# Epoch 00194: val_acc did not improve from 0.70833
#
# Epoch 00194: ReduceLROnPlateau reducing learning rate to 0.0008333333333333334.
# Epoch 195/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4054 - acc: 0.9972 - val_loss: 1.9687 - val_acc: 0.6528
#
# Epoch 00195: val_acc did not improve from 0.70833
# Epoch 196/200
# 1439/1439 [==============================] - 5s 3ms/step - loss: 0.4032 - acc: 0.9986 - val_loss: 2.0062 - val_acc: 0.6500
#
# Epoch 00196: val_acc did not improve from 0.70833
# Epoch 197/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.4000 - acc: 0.9979 - val_loss: 2.0247 - val_acc: 0.6583
#
# Epoch 00197: val_acc did not improve from 0.70833
# Epoch 198/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.3959 - acc: 0.9979 - val_loss: 2.0739 - val_acc: 0.6667
#
# Epoch 00198: val_acc did not improve from 0.70833
# Epoch 199/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.3971 - acc: 0.9993 - val_loss: 2.0549 - val_acc: 0.6528
#
# Epoch 00199: val_acc did not improve from 0.70833
# Epoch 200/200
# 1439/1439 [==============================] - 4s 3ms/step - loss: 0.3952 - acc: 0.9986 - val_loss: 2.0801 - val_acc: 0.6583
#
# Epoch 00200: val_acc did not improve from 0.70833

# %%
training_loss = hist.history['loss']
val_loss = hist.history['val_loss']

plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
training_acc = hist.history['acc']
val_acc = hist.history['val_acc']

plt.plot(training_acc, label="training_accuracy")
plt.plot(val_acc, label="validation_accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
from keras.models import Model, load_model
model1_name = "3DCNN_LRN_112_6_jester"
model1_path = os.path.join(save_dir, model1_name)
model1 = load_model(model1_path)

# %%
test_pred =model1.predict(X_train_new[50:70])
result = np.argmax(test_pred, axis =1)
print(result)
# Out:
# [1 2 3 1 1 1 4 0 2 1 1 3 1 4 4 2 4 4 0 0]

# %%
img_array = X_train_new[50]

# %%
plt.imshow(img_array[0,:,:,9])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-b36be9350f5a> in <module>()
#       1
# ----> 2 plt.imshow(img_array[0,:,:,9])
#
# IndexError: index 9 is out of bounds for axis 3 with size 3

# %%
#np.argmax(y_val_new[0:20],axis =1)

# %%
from sklearn.metrics import confusion_matrix
met = confusion_matrix(np.argmax(y_val_new,axis =1), np.argmax(model1.predict(X_val_new),axis =1))
print(met)
# Out:
# [[32 24  2  1  1  0]
#  [24 38  1  0  5  3]
#  [ 4  0 42  1  3  6]
#  [ 2  1  4 40  3  3]
#  [ 4  1  3  2 50  2]
#  [ 0  1  1  2  1 53]]

# %%
import itertools
def confusion_matrix_plot(cm, classes, 
                          title='Normalized Confusion Matrix', 
                          normalize=True, 
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    plt.subplots(1, 1, figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
confusion_matrix_plot(met, classes=['Backward', 'Forward', 'Stop', 'Swiping Left', 'Swiping Right','No Gesture'])

# %%
from keras.models import Model, load_model
model2_name = "3DCNN_HRN_224_5"
model2_path = os.path.join(save_dir, model2_name)
model2 = load_model(model2_path)

# %%
met = confusion_matrix(np.argmax(y_val_new,axis =1), np.argmax(model1.predict(X_val_new)+model2.predict(X_val_new),axis =1))
print(met)
# Out:
# [[26  5  0  0  4]
#  [ 0 24  0  0  0]
#  [ 0  0 14  9  1]
#  [ 1  0 10  9  1]
#  [ 0  0  0  1 16]]
